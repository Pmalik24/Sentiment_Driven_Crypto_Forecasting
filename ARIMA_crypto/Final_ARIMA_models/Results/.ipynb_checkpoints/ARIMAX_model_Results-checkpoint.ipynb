# %%
import pandas as pd 
train = pd.read_csv('training_residuals_nodiff.csv')
test = pd.read_csv('test_residuals_nodiff.csv')

# %%
train
# Out:
#              Date  Coin    actual  predicted  Residual
# 0      2021-01-01  aave -0.408932  -0.274667 -0.134265
# 1      2021-01-02  aave -0.409344  -0.543491  0.134147
# 2      2021-01-03  aave -0.408719  -0.386479 -0.022240
# 3      2021-01-04  aave -0.407123  -0.407855  0.000732
# 4      2021-01-05  aave -0.406690  -0.405485 -0.001204
# ...           ...   ...       ...        ...       ...
# 14360  2023-04-21   zrx -0.416005  -0.415998 -0.000007
# 14361  2023-04-22   zrx -0.416004  -0.416011  0.000006
# 14362  2023-04-23   zrx -0.416005  -0.416007  0.000002
# 14363  2023-04-24   zrx -0.416005  -0.416006  0.000002
# 14364  2023-04-25   zrx -0.416004  -0.415990 -0.000014
#
# [14365 rows x 5 columns]

# %%
# Training Residuals 
for coin in train['Coin'].unique():
    coin_data = train[train['Coin'] == coin]
    plt.figure(figsize=(12, 6))
    plt.plot(coin_data['Date'], coin_data['Residual'], color='red')
    plt.title(f'Training Residuals {coin}')
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.show()

# %%
# Test Residuals 
for coin in test['Coin'].unique():
    coin_data = test[test['Coin'] == coin]
    plt.figure(figsize=(12, 6))
    plt.plot(coin_data['Date'], coin_data['Residual'], color='red')
    plt.title(f'Test Residuals {coin}')
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.show()

# %%
#Training Actual v. Predicted
for coin in train['Coin'].unique():
    coin_data = train[train['Coin'] == coin]
    plt.figure(figsize=(12, 6))
    plt.plot(coin_data['Date'], coin_data['actual'], label='actual', color='blue')
    plt.plot(coin_data['Date'], coin_data['predicted'], label='Predicted', color='red')
    plt.title(f'Training Actual vs Predicted Values for {coin}')
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.legend()
    plt.show()
